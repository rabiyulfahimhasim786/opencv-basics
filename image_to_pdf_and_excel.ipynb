# %% [markdown]
# <a href="https://colab.research.google.com/github/rabiyulfahimhasim786/opencv-basics/blob/main/image_to_pdf_and_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install -U pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
pip install Pillow==9.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from PIL import Image
import pytesseract

#image = 'PATH/TO/IMAGE'
image = 'invoice.png'
configuration = '--psm 11 --oem 3'
text = pytesseract.image_to_string(Image.open(image), lang="eng", config=configuration)
print(text)
# Out:
# Delur)
#
# Brand
#
# a
#
# Invoice to:
#
# Dwyane Cl.
#
# k
#
# Invoice#
#
# 52148
#
# 24 Dummy Street Ai
#
# Date
#
# 01/02 / 2020
#
# 570xx59%
#
# Location, Lorem Ipsum,
#
# su.
#
# Item Description
#
# Price
#
# yy.
#
# Total
#
# Lorem Ipsum Dolor
#
# $50.00
#
# $50.00
#
# Pellentesqu
#
# neque ligula
#
# $20.00
#
# $60.00
#
# interdum et malesuada fames
#
# $10.00
#
# $20.00
#
# Vivamus volutpat faucibus
#
# $90.00
#
# $90.00
#
# ‘Thank you for your business
#
# ‘Sub Total:
#
# $220.00,
#
# Tax:
#
# 0.00%
#
# Payment Info:
#
# Account
#
# 1234 5670 9012
#
# Total:
#
# $220.00
#
# Ale wame:
#
# ore
#
# i
#
# Bank Decal:
#
# ‘Add your bank details
#
# Terms & Conditions
#
# Lorem Ipsum dotor sit amet.
#
# consectetutadipisein
#
# Fosee
#
# dignissim pretium consectetur.
#
# Authorised sign

# %%
from PIL import Image
import pytesseract

#image = 'PATH/TO/IMAGE'
image = 'invoice.png'
configuration = '--psm 11 --oem 3'
pdf = pytesseract.image_to_pdf_or_hocr(Image.open(image), lang="eng", extension='pdf', config=configuration)
print(pdf)
# Out:
# b'%PDF-1.5\n%\xde\xad\xbe\xeb\n1 0 obj\n<<\n  /Type /Catalog\n  /Pages 2 0 R\n>>\nendobj\n3 0 obj\n<<\n  /BaseFont /GlyphLessFont\n  /DescendantFonts [ 4 0 R ]\n  /Encoding /Identity-H\n  /Subtype /Type0\n  /ToUnicode 6 0 R\n  /Type /Font\n>>\nendobj\n4 0 obj\n<<\n  /BaseFont /GlyphLessFont\n  /CIDToGIDMap 5 0 R\n  /CIDSystemInfo\n  <<\n     /Ordering (Identity)\n     /Registry (Adobe)\n     /Supplement 0\n  >>\n  /FontDescriptor 7 0 R\n  /Subtype /CIDFontType2\n  /Type /Font\n  /DW 500\n>>\nendobj\n5 0 obj\n<<\n  /Length 210 /Filter /FlateDecode\n>>\nstream\nx\x9c\xec\xc2\x01\t\x00\x00\x00\x02\xa0\xfa\x7f\xba!\x89\xa6\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80{\x03\x00\x00\xff\xff\xec\xc2\x01\r\x00\x00\x00\xc2 \xdf\xbf\xb4E\x18\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xeb\x00\x00\x00\xff\xff\xec\xc2\x01\r\x00\x00\
# ...

# %%
file = open("invoice.txt", "w+")
file.write(text)
file.close()

# %%
with open('invoice.pdf',mode ='w+b') as file:
  file.write(pdf)
  #file.close()
  #print(result)

# %%
# !pip install camelot-py[cv] tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !sudo apt install ghostscript
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono gsfonts libcupsfilters1 libcupsimage2
#   libgs9 libgs9-common libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x poppler-utils fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 11 newly installed, 0 to remove and 42 not upgraded.
# Need to get 18.6 kB/14.1 MB of archives.
# ...

# %%
import camelot as cam
table = cam.read_pdf("invoice.pdf", pages = 'all', flavor = 'stream')

# %%
table
# Out:
# <TableList n=1>

# %%
table[0].parsing_report
# Out:
# {'accuracy': 81.47, 'order': 1, 'page': 1, 'whitespace': 60.87}

# %%
print(table[0])
table[0].df
#table[0].to_excel("3.xlsx", index=False)
# Out:
# <Table shape=(23, 6)>
#                        0                               1                2  \
# 0
# 1            Invoice to:
# 2
# 3            DwyaneClark
# 4        24 DummyStreetA
# 5                                 Location, Lorem ipsum,
# 6               570xx59%
# 7                    SL.                Item Description            Price
# 8                      1               Lorem Ipsum Dolor           $50.00
# 9                      2      Pellentesque\nneque ligula           $20.00
# 10                     3     interdum et malesuada fames           $10.00
# 11                     4         Vivamusvolutpatfaucibus           $90.00
# 12                          ‘Thank you for your business
# 13
# 14          PaymentInfo:
# 15             Account #                     12345670902
# 16               Nename:                    Lorem\nlosum
# 17         Bank Details:           Add your bank detalls
# 18                                    Terms & Conditions
# ...

# %%
# export to HTML
table.export("1.html", f="html")
#https://www.geeksforgeeks.org/convert-html-table-into-csv-file-in-python/

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Importing the required modules
import os
import sys
import pandas as pd
from bs4 import BeautifulSoup

path = '1-page-1-table-1.html'

# empty list
data = []

# for getting the header from
# the HTML file
list_header = []
soup = BeautifulSoup(open(path),'html.parser')
header = soup.find_all("table")[0].find("tr")

for items in header:
	try:
		list_header.append(items.get_text())
	except:
		continue

# for getting the data
HTML_data = soup.find_all("table")[0].find_all("tr")[1:]

for element in HTML_data:
	sub_data = []
	for sub_element in element:
		try:
			sub_data.append(sub_element.get_text())#.strip('\n')
		except:
			continue
	data.append(sub_data)

# Storing the data into Pandas
# DataFrame
dataFrame = pd.DataFrame(data = data, columns = list_header)

# Converting Pandas DataFrame
# into CSV file
dataFrame.to_csv('k4.csv')

# %%
dataFrame
# Out:
#                            0                               1                2  \
# 0    0
# 1    1           Invoice to:
# 2    2
# 3    3           DwyaneClark
# 4    4       24 DummyStreetA
# 5    5                                Location, Lorem ipsum,
# 6    6              570xx59%
# 7    7                   SL.                Item Description            Price
# 8    8                     1               Lorem Ipsum Dolor           $50.00
# 9    9                     2      Pellentesque\nneque ligula           $20.00
# 10  10                     3     interdum et malesuada fames           $10.00
# 11  11                     4         Vivamusvolutpatfaucibus           $90.00
# 12  12                          ‘Thank you for your business
# 13  13
# 14  14          PaymentInfo:
# 15  15             Account #                     12345670902
# 16  16               Nename:                    Lorem\nlosum
# 17  17         Bank Details:           Add your bank detalls
# ...

# %%
# Importing pandas
import pandas as pd
  
# The webpage URL whose table we want to extract
#url = "https://www.geeksforgeeks.org/extended-operators-in-relational-algebra/"
url = '1-page-1-table-1.html'
# Assign the table data to a Pandas dataframe
table = pd.read_html(url)[0]
  
# Store the dataframe in Excel file
table.to_excel("invoice.xlsx")
#https://www.geeksforgeeks.org/python-convert-an-html-table-into-excel/?ref=lbp

# %%
table
# Out:
#     Unnamed: 0                     0                               1  \
# 0            0                   NaN                             NaN
# 1            1           Invoice to:                             NaN
# 2            2                   NaN                             NaN
# 3            3           DwyaneClark                             NaN
# 4            4       24 DummyStreetA                             NaN
# 5            5                   NaN          Location, Lorem ipsum,
# 6            6              570xx59%                             NaN
# 7            7                   SL.                Item Description
# 8            8                     1               Lorem Ipsum Dolor
# 9            9                     2      Pellentesque\nneque ligula
# 10          10                     3     interdum et malesuada fames
# 11          11                     4         Vivamusvolutpatfaucibus
# 12          12                   NaN  âThank you for your business
# ...
